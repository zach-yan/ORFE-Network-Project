# %% [markdown]
# <a href="https://colab.research.google.com/github/zach-yan/ORFE-Network-Project/blob/main/ORF_387_PoC_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# List of researchers with their affiliated institutions and departments
master_people_list = [
    ("AAA", "Amir Ali Ahmadi", "Princeton University", "Operations Research and Financial Engineering", "optimization", "statistics and ML", "pure theory", "robotics"),
    ("Rene Carmona", "Rene Carmona", "Princeton University", "Operations Research and Financial Engineering", "probability", "game theory", "finance", "energy"),
    ("Matias Cattaneo", "Matias Cattaneo", "Princeton University", "Operations Research and Financial Engineering", "statistics and ML", "financial engineering", "pure theory", "finance"),
    ("Jianqing Fan", "Jianqing Fan", "Princeton University", "Operations Research and Financial Engineering", "statistics and ML", "financial engineering", "healthcare", "finance"),
    ("Jason Klusowski", "Jason Klusowski", "Princeton University", "Operations Research and Financial Engineering", "statistics and ML", "probability", "natural language processing", "pure theory"),
    ("Kornhauser", "Alain Kornhauser", "Princeton University", "Operations Research and Financial Engineering", "optimization", "statistics and ML", "transportation/logistics", "robotics"),
    ("Kulkarni", "Sanjeev Kulkarni", "Princeton University", "Electrical and Computer Engineering", "statistics and ML", "probability", "pure theory", "networks/telecommunications"),
    ("William Massey", "William Massey", "Princeton University", "Operations Research and Financial Engineering", "probability", "optimization", "networks/telecommunications", "transportation/logistics"),
    ("John Mulvey", "John Mulvey", "Princeton University", "Operations Research and Financial Engineering", "optimization", "financial engineering", "finance", "energy"),
    ("Liza", "Liza Rebrova", "Princeton University", "Operations Research and Financial Engineering", "probability", "statistics and ML", "pure theory", "natural language processing"),
    ("Ronnie Sircar", "Ronnie Sircar", "Princeton University", "Operations Research and Financial Engineering", "financial engineering", "game theory", "finance", "energy"),
    ("Mete Soner", "Mete Soner", "Princeton University", "Operations Research and Financial Engineering", "financial engineering", "probability", "finance", "pure theory"),
    ("Stellato", "Bartolomeo Stellato", "Princeton University", "Operations Research and Financial Engineering", "optimization", "statistics and ML", "robotics", "finance"),
    ("Ludvic Tangpi", "Ludovic Tangpi", "Princeton University", "Operations Research and Financial Engineering", "probability", "financial engineering", "finance", "pure theory"),
    ("D. Bertsimas", "Dimitris Bertsimas", "Massachusetts Institute of Technology", "Sloan School of Management", "optimization", "statistics and ML", "healthcare", "supply chain/revenue management"),
    ("J. N. Tsitsiklis", "John Tsitsiklis", "Massachusetts Institute of Technology", "Electrical Engineering and Computer Science", "optimization", "probability", "pure theory", "networks/telecommunications"),
    ("P. A. Parrilo", "Pablo A. Parrilo", "Massachusetts Institute of Technology", "Electrical Engineering and Computer Science", "optimization", "statistics and ML", "pure theory", "robotics"),
    ("O. Gunluk", "Oktay Gunluk", "Cornell University", "Operations Research and Information Engineering", "optimization", "statistics and ML", "transportation/logistics", "pure theory"),
    ("W. Whitt", "Ward Whitt", "Columbia University", "Industrial Engineering and Operations Research", "probability", "optimization", "networks/telecommunications", "pure theory"),
    ("S. Boyd", "Stephen Boyd", "Stanford University", "Electrical Engineering", "optimization", "statistics and ML", "pure theory", "supply chain/revenue management"),
    ("Rocio Titiunik", "Rocio Titiunik", "Princeton University", "Politics", "statistics and ML", "financial engineering", "public policy", "pure theory"),
    ("Michael Jansson", "Michael Jansson", "UC Berkeley", "Economics", "financial engineering", "statistics and ML", "pure theory", "public policy"),
    ("L. Vandenberghe", "Lieven Vandenberghe", "UCLA", "Electrical and Computer Engineering", "optimization", "statistics and ML", "pure theory", "networks/telecommunications"),
    ("E. Candes", "Emmanuel Candes", "Stanford University", "Mathematics and Statistics", "statistics and ML", "optimization", "pure theory", "healthcare"),
    ("Y. Nesterov", "Yurii Nesterov", "UC Louvain", "Center for Operations Research and Econometrics", "optimization", "statistics and ML", "pure theory", "finance"),
    ("R. Freund", "Robert Freund", "Massachusetts Institute of Technology", "Sloan School of Management", "optimization", "statistics and ML", "pure theory", "supply chain/revenue management"),
    ("J. Dunn", "Jack Dunn", "Massachusetts Institute of Technology", "Operations Research Center", "optimization", "statistics and ML", "pure theory", "supply chain/revenue management"),
    ("D. P. Bertsekas", "Dimitri Bertsekas", "Massachusetts Institute of Technology", "Electrical Engineering and Computer Science", "optimization", "probability", "pure theory", "networks/telecommunications"),
    ("V. Borkar", "Vivek Borkar", "IIT Bombay", "Electrical Engineering", "probability", "optimization", "pure theory", "networks/telecommunications"),
    ("P. W. Glynn", "Peter Glynn", "Stanford University", "Management Science and Engineering", "probability", "optimization", "pure theory", "networks/telecommunications"),
    ("J. Abate", "Joseph Abate", "Columbia University", "Industrial Engineering and Operations Research", "probability", "optimization", "networks/telecommunications", "pure theory"),
    ("S. Ahmed", "Shabbir Ahmed", "Georgia Institute of Technology", "Industrial and Systems Engineering", "optimization", "probability", "supply chain/revenue management", "transportation/logistics"),
    ("M. Goemans", "Michel Goemans", "Massachusetts Institute of Technology", "Mathematics", "optimization", "probability", "pure theory", "networks/telecommunications"),
    ("N. Kallus", "Nathan Kallus", "Cornell University", "Operations Research and Information Engineering", "statistics and ML", "optimization", "supply chain/revenue management", "public policy"),
    ("A. Jacquillat", "Alex Jacquillat", "Massachusetts Institute of Technology", "Sloan School of Management", "optimization", "statistics and ML", "transportation/logistics", "healthcare"),
    ("M. Sim", "Melvyn Sim", "National University of Singapore", "NUS Business School", "optimization", "probability", "supply chain/revenue management", "finance"),
    ("D. Iancu", "Dan Iancu", "Stanford University", "Graduate School of Business", "optimization", "financial engineering", "supply chain/revenue management", "finance"),
    ("V. Digalakis Jr.", "Vassilis Digalakis Jr.", "Boston University Questrom School of Business", "Operations and Technology Management", "optimization", "statistics and ML", "healthcare", "pure theory"),
    ("M. L. Li", "Michael Lingzhi Li", "Harvard Business School", "Technology and Operations Management", "statistics and ML", "optimization", "healthcare", "supply chain/revenue management"),
    ("A. Thiele", "Aurelie Thiele", "Southern Methodist University", "Engineering Management, Information, and Systems", "optimization", "financial engineering", "supply chain/revenue management", "pure theory"),
    ("B. Van Roy", "Benjamin Van Roy", "Stanford University", "Management Science and Engineering", "statistics and ML", "optimization", "pure theory", "finance"),
    ("C. H. Papadimitriou", "Christos Papadimitriou", "Columbia University", "Computer Science", "probability", "game theory", "pure theory", "networks/telecommunications"),
    ("A. Olshevsky", "Alex Olshevsky", "Boston University", "Electrical and Computer Engineering", "optimization", "probability", "networks/telecommunications", "robotics"),
    ("R. Johari", "Ramesh Johari", "Stanford University", "Management Science and Engineering", "game theory", "probability", "networks/telecommunications", "supply chain/revenue management"),
    ("M. C. Grant", "Michael C. Grant", "Stanford University", "Electrical Engineering", "optimization", "statistics and ML", "pure theory", "finance"),
    ("L. Xiao", "Lin Xiao", "Stanford University", "Electrical Engineering", "optimization", "statistics and ML", "pure theory", "networks/telecommunications"),
    ("N. Parikh", "Neal Parikh", "Columbia University", "School of International and Public Affairs", "optimization", "statistics and ML", "finance", "public policy"),
    ("A. Agrawal", "Akshay Agrawal", "Stanford University", "Electrical Engineering", "optimization", "statistics and ML", "pure theory", "finance"),
    ("A. Orfanoudaki", "Agni Orfanoudaki", "University of Oxford", "Saïd Business School", "optimization", "statistics and ML", "healthcare", "finance"),
    ("C. McCord", "Chris McCord", "Massachusetts Institute of Technology", "Operations Research Center", "optimization", "statistics and ML", "pure theory", "supply chain/revenue management"),
    ("H. Wiberg", "Holly Wiberg", "Carnegie Mellon University", "Heinz College", "optimization", "statistics and ML", "healthcare", "public policy"),
    ("B. Sturt", "Bradley Sturt", "University of Illinois Chicago", "Information and Decision Sciences", "optimization", "statistics and ML", "public policy", "supply chain/revenue management"),
    ("A. Delarue", "Arthur Delarue", "Georgia Institute of Technology", "Industrial and Systems Engineering", "optimization", "statistics and ML", "transportation/logistics", "public policy"),
    ("O. Skali Lami", "Omar Skali Lami", "Massachusetts Institute of Technology", "Operations Research Center", "optimization", "statistics and ML", "healthcare", "supply chain/revenue management"),
    ("A. Paskov", "Alex Paskov", "Massachusetts Institute of Technology", "Operations Research Center", "optimization", "statistics and ML", "finance", "pure theory"),
    ("A. Ozdaglar", "Asuman Ozdaglar", "Massachusetts Institute of Technology", "Laboratory for Information & Decision Systems", "optimization", "game theory", "networks/telecommunications", "pure theory"),
    ("A. Nedic", "Angelia Nedić", "Arizona State University", "School of Electrical, Computer and Energy Engineering", "optimization", "statistics and ML", "networks/telecommunications", "pure theory"),
    ("A. Majumdar", "Anirudha Majumdar", "Princeton University", "Mechanical and Aerospace Engineering", "optimization", "statistics and ML", "robotics", "pure theory"),
    ("J. Saunderson", "James Saunderson", "Monash University", "Electrical and Computer Systems Engineering", "optimization", "statistics and ML", "pure theory", "robotics"),
    ("R. Thomas", "Rekha Thomas", "University of Washington", "Mathematics", "optimization", "probability", "pure theory", "networks/telecommunications"),
    ("G. Chesi", "Graziano Chesi", "University of Hong Kong", "Electrical and Computer Engineering", "optimization", "statistics and ML", "pure theory", "networks/telecommunications"),
    ("S. Dash", "Sanjeeb Dash", "Rice University", "Computational and Applied Mathematics", "optimization", "probability", "pure theory", "networks/telecommunications"),
    ("M. Molinaro", "Marco Molinaro", "PUC-Rio", "Computer Science", "optimization", "probability", "pure theory", "supply chain/revenue management"),
    ("S.-H. Kim", "Seong-Hee Kim", "Georgia Institute of Technology", "Industrial and Systems Engineering", "probability", "optimization", "networks/telecommunications", "pure theory"),
    ("J. Zhang", "Jiheng Zhang", "Hong Kong University of Science and Technology", "Industrial Engineering and Decision Analytics", "probability", "optimization", "supply chain/revenue management", "networks/telecommunications"),
    ("J. Dong", "Jing Dong", "Columbia University Graduate School of Business", "Decision, Risk, and Operations", "probability", "optimization", "healthcare", "networks/telecommunications"),
    ("A. Braverman", "Anton Braverman", "Northwestern University", "Kellog School of Business", "probability", "optimization", "healthcare", "pure theory"),
    ("E. Chu", "Eric Chu", "Massachusetts Institute of Technology", "Media Lab", "optimization", "statistics and ML", "robotics", "transportation/logistics"),
    ("Y. Chen", "Yuxin Chen", "University of Pennsylvania", "Statistics and Data Science", "optimization", "statistics and ML", "pure theory", "healthcare"),
    ("S. Diamond", "Stephen Diamond", "Stanford University", "Computer Science", "optimization", "statistics and ML", "finance", "energy"),
    ("M. Ø. Nielsen", "Morten Ørregaard Nielsen", "Aarhus University", "Economics", "financial engineering", "statistics and ML", "finance", "pure theory"),
    ("D. Chetverikov", "Denis Chetverikov", "UCLA", "Economics", "financial engineering", "statistics and ML", "finance", "pure theory"),
    ("I. Fernandez-Val", "Ivan Fernandez-Val", "Boston University", "Economics", "financial engineering", "statistics and ML", "public policy", "pure theory"),
    ("U. Müller", "Ulrich Müller", "Princeton University", "Economics", "financial engineering", "statistics and ML", "finance", "pure theory"),
    ("W. Newey", "Whitney Newey", "Massachusetts Institute of Technology", "Economics", "financial engineering", "statistics and ML", "public policy", "pure theory"),
    ("J.-S. Pang", "Jong-Shi Pang", "University of Southern California", "Industrial and Systems Engineering", "optimization", "game theory", "pure theory", "networks/telecommunications"),
    ("D. P. Palomar", "Daniel P. Palomar", "Hong Kong University of Science and Technology", "Electronic and Computer Engineering", "optimization", "financial engineering", "finance", "networks/telecommunications"),
    ("V. Chandrasekaran", "Venkat Chandrasekaran", "Caltech", "Computing and Mathematical Sciences", "optimization", "statistics and ML", "pure theory", "networks/telecommunications"),
    ("M. Fazel", "Maryam Fazel", "University of Washington", "Electrical and Computer Engineering", "optimization", "statistics and ML", "pure theory", "robotics"),
    ("C. Sabatti", "Chiara Sabatti", "Stanford University", "Statistics", "statistics and ML", "probability", "healthcare", "pure theory"),
    ("L. Janson", "Lucas Janson", "Harvard University", "Statistics", "statistics and ML", "probability", "pure theory", "healthcare"),
    ("M. Soltanolkotabi", "Mahdi Soltanolkotabi", "University of Southern California", "Electrical and Computer Engineering", "optimization", "statistics and ML", "pure theory", "healthcare"),
    ("J. Romberg", "Justin Romberg", "Georgia Institute of Technology", "Electrical and Computer Engineering", "optimization", "statistics and ML", "networks/telecommunications", "pure theory"),
    ("T. Tao", "Terence Tao", "UCLA", "Mathematics", "probability", "optimization", "pure theory", "networks/telecommunications"),
    ("D. Donoho", "David Donoho", "Stanford University", "Statistics", "statistics and ML", "probability", "pure theory", "networks/telecommunications"),
    ("A. Nemirovski", "Arkadi Nemirovski", "Georgia Institute of Technology", "Industrial and Systems Engineering", "optimization", "statistics and ML", "pure theory", "finance"),
    ("S. Bubeck", "Sébastien Bubeck", "Princeton University", "Operations Research and Financial Engineering", "optimization", "statistics and ML", "pure theory", "natural language processing"),
    ("V. Spokoiny", "Vladimir Spokoiny", "Humboldt University", "Mathematics", "statistics and ML", "probability", "pure theory", "finance"),
    ("P. Grigas", "Paul Grigas", "UC Berkeley", " Industrial Engineering and Operations Research", "optimization", "statistics and ML", "supply chain/revenue management", "pure theory"),
    ("H. Lu", "Haihao Lu", "University of Chicago", "Booth School of Business", "optimization", "statistics and ML", "pure theory", "supply chain/revenue management"),
    ("X. Chen", "Xin Chen", "Georgia Institute of Technology", "Industrial and Systems Engineering", "optimization", "probability", "supply chain/revenue management", "transportation/logistics"),
    ("J. P. Vielma", "Juan Pablo Vielma", "Massachusetts Institute of Technology", "Sloan School of Management", "optimization", "statistics and ML", "pure theory", "energy"),
    ("H. Yu", "Huizhen Yu", "University of Alberta", "Computing Science", "optimization", "probability", "pure theory", "robotics"),
    ("S. Shreve", "Steven Shreve", "Carnegie Mellon University", "Mathematical Sciences", "probability", "financial engineering", "finance", "pure theory"),
    ("S. Bhatnagar", "Shalabh Bhatnagar", "Indian Institute of Science", "Computer Science and Automation", "optimization", "probability", "networks/telecommunications", "transportation/logistics"),
    ("K. S. Narendra", "K. S. Narendra", "Yale University", "Electrical and Computer Engineering", "optimization", "probability", "networks/telecommunications", "robotics"),
    ("S. Juneja", "Sandeep Juneja", "Ashoka University", "Computer Science", "probability", "financial engineering", "finance", "pure theory"),
    ("J. Blanchet", "Jose Blanchet", "Stanford University", "Management Science and Engineering", "probability", "optimization", "pure theory", "finance"),
    ("H. Lam", "Henry Lam", "Columbia University", "Industrial Engineering and Operations Research", "probability", "statistics and ML", "pure theory", "finance"),
    ("J. M. Harrison", "J. Michael Harrison", "Stanford University", "Stanford Graduate School of Business", "probability", "financial engineering", "pure theory", "finance"),
    ("S. N. Lahiri", "Soumendra N. Lahiri", "Washington University in St. Louis", "Statistics and Data Science", "statistics and ML", "probability", "pure theory", "healthcare"),
    ("Q. Zhang", "Qiangyang Zhang", "Columbia University", "Economics", "optimization", "statistics and ML", "pure theory", "finance"),
    ("X. Zhang", "Xiaowei Zhang", "Hong Kong University of Science and Technology", "Industrial Engineering and Decision Analytics", "optimization", "probability", "finance", "supply chain/revenue management"),
    ("J. Hasenbein", "John Hasenbein", "University of Texas at Austin", "Mechanical Engineering", "optimization", "probability", "networks/telecommunications", "supply chain/revenue management"),
    ("Jim Luedtke", "Jim Luedtke", "University of Wisconsin-Madison", "Industrial & Systems Engineering", "optimization", "statistics and ML", "energy", "supply chain/revenue management"),
    ("A. Shapiro", "Alexander Shapiro", "Georgia Institute of Technology", "Industrial and Systems Engineering", "optimization", "statistics and ML", "pure theory", "supply chain/revenue management"),
    ("D. Williamson", "David Williamson", "Cornell University", "Operations Research and Information Engineering", "optimization", "game theory", "pure theory", "networks/telecommunications"),
    ("A. Lodi", "Andrea Lodi", "Cornell Tech", "Operations Research and Information Engineering ", "optimization", "statistics and ML", "pure theory", "transportation/logistics"),
    ("P. Baptiste", "Philippe Baptiste", "Université Paris-Saclay", "Computer Science", "optimization", "statistics and ML", "transportation/logistics", "networks/telecommunications"),
    ("M. Laurent", "Monique Laurent", "CWI", "Networks and Optimization", "optimization", "probability", "pure theory", "networks/telecommunications"),
    ("R. K. Ahuja", "R. K. Ahuja", "University of Florida", "Industrial and Systems Engineering", "optimization", "statistics and ML", "transportation/logistics", "networks/telecommunications"),
    ("X. Mao", "Xiaojie Mao", "Tsinghua University", "Management Science and Engineering", "statistics and ML", "optimization", "supply chain/revenue management", "pure theory"),
    ("V. Zhang", "Vickie Zhang", "Cornell University", "Operations Research and Information Engineering", "statistics and ML", "optimization", "supply chain/revenue management", "healthcare"),
    ("M. Ban", "Gah-Yi Ban", "Imperial College London", "Analytics & Operations", "statistics and ML", "optimization", "supply chain/revenue management", "finance"),
]
# Define the column names based on the data structure
columns = [
    "Short_Name",
    "Full_Name",
    "Institution",
    "Department",
    "Subject of Interest 1",
    "Subject of Interest 2",
    "Application of Interest 1",
    "Application of Interest 2"
]

# Create the DataFrame
df_researchers = pd.DataFrame(master_people_list, columns=columns)
nodes_df = pd.DataFrame(master_people_list, columns=['Id', 'Label', 'Institution', 'department', 'Subject 1', 'Subject 2', 'Application 1', 'Application 2'])

# Display the first few rows to verify
display(df_researchers)
# Out:
#           Short_Name        Full_Name              Institution  \
# 0                AAA  Amir Ali Ahmadi     Princeton University
# 1       Rene Carmona     Rene Carmona     Princeton University
# 2    Matias Cattaneo  Matias Cattaneo     Princeton University
# 3       Jianqing Fan     Jianqing Fan     Princeton University
# 4    Jason Klusowski  Jason Klusowski     Princeton University
# ..               ...              ...                      ...
# 109       M. Laurent  Monique Laurent                      CWI
# 110      R. K. Ahuja      R. K. Ahuja    University of Florida
# 111           X. Mao      Xiaojie Mao      Tsinghua University
# 112         V. Zhang     Vickie Zhang       Cornell University
# 113           M. Ban       Gah-Yi Ban  Imperial College London
#
#                                           Department Subject of Interest 1  \
# 0      Operations Research and Financial Engineering          optimization
# ...

# %% [markdown]
# We ensure everyone has a department assigned to them.

# %%
# Assuming master_people_list is already defined as above

def find_missing_departments(data):
    print(f"{'Index':<6} | {'Name':<25} | {'Institution'}")
    print("-" * 60)

    missing_count = 0
    for i, entry in enumerate(data):
        # The department is at index 3 in the tuple
        department = entry[3]

        if department == "":
            name = entry[1]
            institution = entry[2]
            print(f"{i:<6} | {name:<25} | {institution}")
            missing_count += 1

    print("-" * 60)
    print(f"Total entries missing a department: {missing_count}")

# Run the check
find_missing_departments(master_people_list)
# Out:
# Index  | Name                      | Institution
# ------------------------------------------------------------
# ------------------------------------------------------------
# Total entries missing a department: 0

# %%
edges_data = [
    ("Rene Carmona", "F. Delarue", 9),
    ("Rene Carmona", "M. Laurière", 7),
    ("Rene Carmona", "J.-P. Fouque", 4),
    ("Rene Carmona", "M. Ludkovski", 2),
    ("Rene Carmona", "Ronnie Sircar", 2),
    ("Ronnie Sircar", "J.-P. Fouque", 22),
    ("Ronnie Sircar", "M. Ludkovski", 4),
    ("Matias Cattaneo", "Jason Klusowski", 2),
    ("Matias Cattaneo", "Michael Jansson", 19),
    ("Matias Cattaneo", "Rocio Titiunik", 11),
    ("Matias Cattaneo", "Sebastian Calonico", 5),
    ("Matias Cattaneo", "Whitney Newey", 2),
    ("Jason Klusowski", "Jianqing Fan", 3),
    ("John Mulvey", "H.V. Poor", 5),
    ("Jianqing Fan", "Whitney Newey", 2),
    ("Stellato", "D. Bertsimas", 8),
    ("Stellato", "S. Boyd", 5),
    ("S. Boyd", "M. C. Grant", 16),
    ("S. Boyd", "L. Xiao", 14),
    ("S. Boyd", "N. Parikh", 12),
    ("J. N. Tsitsiklis", "B. Van Roy", 18),
    ("J. N. Tsitsiklis", "C. H. Papadimitriou", 11),
    ("J. N. Tsitsiklis", "A. Olshevsky", 15),
    ("Kulkarni", "H.V. Poor", 15),
    ("Kulkarni", "S. Verdú", 12),
    ("Stellato", "G. Hall", 2),
    ("AAA", "G. Hall", 1),
    ("AAA", "J. N. Tsitsiklis", 1),
    ("D. Bertsimas", "O. Skali Lami", 3),
    ("D. Bertsimas", "A. Delarue", 6),
    ("D. Bertsimas", "V. Digalakis Jr.", 4),
    ("Jack Dunn", "Agni Orfanoudaki", 2),
    ("Jack Dunn", "V. Digalakis Jr.", 4),
    ("D. Bertsimas", "A. Orfanoudaki", 8),
    ("O. Skali Lami", "Agni Orfanoudaki", 3),
    ("Kornhauser", "K. Marocchini", 3),
    ("Kornhauser", "S. Zhu", 4),
    ("Kornhauser", "J. Lutin", 3),
    ("Kornhauser", "Jun Liu", 4),
    ("Kornhauser", "Kara Kockelman", 17),
    ("Kornhauser", "Neil Quarles", 2),
    ("Jianqing Fan", "Lou Z.", 6),
    ("Jianqing Fan", "Gu Y.", 7),
    ("Jianqing Fan", "Fang C.", 2),
    ("Jianqing Fan", "Gao C.", 4),
    ("D. Bertsimas", "Jack Dunn", 10),
    ("Liza", "L Huang", 2),
    ("Liza", "Y Huang", 2),
    ("Liza", "A Kryshchenko", 2),
    ("Liza", "P Li", 2),
    ("Liza", "J Vendrow", 2),
    ("Liza", "MA Iwen", 2),
    ("Liza", "C Haselby", 2),
    ("Stellato", "S. Clarke", 3),
    ("Stellato", "G. Dragotto", 3),
    ("Stellato", "JF Fisac", 2),
    ("Stellato", "Z. Frangella", 2),
    ("Stellato", "T. Diamandis", 2),
    ("Stellato", "M. Udell", 2),
    ("Stellato", "J. Park", 2)
]

edges_df = pd.DataFrame(edges_data, columns=['Source', 'Target', 'Weight'])

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

# First, add all researchers from nodes_df as nodes with their attributes
for index, row in df_researchers.iterrows():
    G.add_node(row['Short_Name'],
               Full_Name=row['Full_Name'],
               Institution=row['Institution'],
               Department=row['Department'],
               Subject1=row['Subject of Interest 1'],
               Subject2=row['Subject of Interest 2'],
               Application1=row['Application of Interest 1'],
               Application2=row['Application of Interest 2'])

# Then, add edges from edges_df. NetworkX will automatically add nodes
# that are in edges_df but not in nodes_df (unknown collaborators).
for _, row in edges_df.iterrows():
    G.add_edge(row['Source'], row['Target'], weight=row['Weight'])

# Remove nodes that have no edges (degree 0)
isolated_nodes = [node for node, degree in dict(G.degree()).items() if degree == 0]
G.remove_nodes_from(isolated_nodes)

# 4. Color Coding Logic
# Re-filter nodes based on the modified graph G
princeton_nodes = [node for node in df_researchers[df_researchers['Institution'] == 'Princeton University']['Short_Name'].tolist() if node in G.nodes()]
anchor_nodes = [node for node in df_researchers[df_researchers['Institution'] != 'Princeton University']['Short_Name'].tolist() if node in G.nodes()]
all_known = set(princeton_nodes + anchor_nodes)
unknown_nodes = [node for node in G.nodes() if node not in all_known]

# Calculate betweenness centrality for node sizing
betweenness_centrality = nx.betweenness_centrality(G)
# Scale node sizes based on betweenness centrality for better visualization
node_sizes = [v * 5000 + 100 for v in betweenness_centrality.values()] # Scale for visibility

# 5. Drawing the Graph
pos = nx.spring_layout(G, k=0.5, iterations=50, seed=42) # k controls distance between nodes
plt.figure(figsize=(15, 12))

# Draw the 3 categories of nodes with sizes based on betweenness centrality
nx.draw_networkx_nodes(G, pos, nodelist=princeton_nodes, node_color='orange', label='Princeton (ORFE)', node_size=[node_sizes[list(G.nodes()).index(node)] for node in princeton_nodes])
nx.draw_networkx_nodes(G, pos, nodelist=anchor_nodes, node_color='skyblue', label='External Anchors (MIT/Stanford/etc.)', node_size=[node_sizes[list(G.nodes()).index(node)] for node in anchor_nodes])
nx.draw_networkx_nodes(G, pos, nodelist=unknown_nodes, node_color='lightgrey', label='Unknown Collaborators', node_size=[node_sizes[list(G.nodes()).index(node)] for node in unknown_nodes])

# Draw edges, scaling the thickness by co-authorship weight
weights = [G[u][v]['weight'] for u, v in G.edges()]
# Check if there are any edges before trying to find max_w
if weights:
    max_w = max(weights)
    scaled_weights = [0.1 + (w / max_w) * 2 for w in weights]
else:
    scaled_weights = [] # No edges, so no scaled weights
nx.draw_networkx_edges(G, pos, width=scaled_weights, alpha=0.3, edge_color='gray')

# Draw text labels ONLY for known/anchored researchers to prevent visual clutter
labels = {node: node for node in princeton_nodes + anchor_nodes}
nx.draw_networkx_labels(G, pos, labels, font_size=8, font_family='sans-serif')

plt.title("Proof-of-Concept Network: ORFE Faculty & Academic Collaborators (Node size by Betweenness Centrality)", fontsize=16)
plt.legend(scatterpoints=1)
plt.axis('off')
plt.tight_layout()
plt.savefig("network_graph.png") # Save the figure as a PNG file
plt.show()

# 6. Save the final synchronized datasets
edges_df.to_csv('final_edges.csv', index=False)
nodes_df.to_csv('final_nodes.csv', index=False)
print("Graph rendered and updated CSVs successfully saved!")
# Out:
# Graph rendered and updated CSVs successfully saved!

# %% [markdown]
# Compute the number of cycles in G

# %%
import networkx as nx

num_cycles = nx.cycle_basis(G)
print(f"Number of cycles in the graph: {len(num_cycles)}")
# Out:
# Number of cycles in the graph: 5

# %% [markdown]
# Search for high-degree nodes

# %%
nodes_connected_to_high_degree_nodes = set()

for node in G.nodes():
    # Get neighbors of the current node
    neighbors = list(G.neighbors(node))

    for neighbor in neighbors:
        # Check if the neighbor has more than one edge (degree > 1)
        if G.degree(neighbor) > 1:
            nodes_connected_to_high_degree_nodes.add(node)
            break # Once one such neighbor is found, move to the next node

print(f"Total nodes connected to a node with more than one edge: {len(nodes_connected_to_high_degree_nodes)}")
print("Nodes connected to a node with more than one edge:")
for node in sorted(list(nodes_connected_to_high_degree_nodes)):
    print(f"- {node}")
# Out:
# Total nodes connected to a node with more than one edge: 59
# Nodes connected to a node with more than one edge:
# - A Kryshchenko
# - A. Delarue
# - A. Olshevsky
# - A. Orfanoudaki
# - AAA
# - Agni Orfanoudaki
# - B. Van Roy
# - C Haselby
# - C. H. Papadimitriou
# - D. Bertsimas
# - F. Delarue
# - Fang C.
# - G. Dragotto
# - G. Hall
# - Gao C.
# - Gu Y.
# - H.V. Poor
# - J Vendrow
# - J. Lutin
# - J. N. Tsitsiklis
# - J. Park
# - J.-P. Fouque
# - JF Fisac
# - Jack Dunn
# - Jason Klusowski
# - Jianqing Fan
# - John Mulvey
# - Jun Liu
# - K. Marocchini
# - Kara Kockelman
# - Kulkarni
# - L Huang
# - L. Xiao
# - Lou Z.
# - M. C. Grant
# - M. Laurière
# - M. Ludkovski
# - M. Udell
# - MA Iwen
# - Matias Cattaneo
# - Michael Jansson
# - N. Parikh
# - Neil Quarles
# - O. Skali Lami
# - P Li
# - Rene Carmona
# - Rocio Titiunik
# - Ronnie Sircar
# - S. Boyd
# - S. Clarke
# - S. Verdú
# - S. Zhu
# - Sebastian Calonico
# - Stellato
# - T. Diamandis
# - V. Digalakis Jr.
# - Whitney Newey
# ...

# %% [markdown]
# ### 4. Calculate Degree Centrality

# %%
degree_centrality = nx.degree_centrality(G)

# Sort nodes by degree centrality in descending order
sorted_degree = sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True)

print("Top 10 nodes by Degree Centrality:")
for node, dc in sorted_degree[:10]:
    print(f"Node: {node}, Degree Centrality: {dc:.4f}")
# Out:
# Top 10 nodes by Degree Centrality:
# Node: Stellato, Degree Centrality: 0.1667
# Node: Liza, Degree Centrality: 0.1167
# Node: Jianqing Fan, Degree Centrality: 0.1000
# Node: Kornhauser, Degree Centrality: 0.1000
# Node: D. Bertsimas, Degree Centrality: 0.1000
# Node: Rene Carmona, Degree Centrality: 0.0833
# Node: Matias Cattaneo, Degree Centrality: 0.0833
# Node: J. N. Tsitsiklis, Degree Centrality: 0.0667
# Node: S. Boyd, Degree Centrality: 0.0667
# Node: Ronnie Sircar, Degree Centrality: 0.0500

# %% [markdown]
# ### 5. Calculate Closeness Centrality

# %%
closeness_centrality = nx.closeness_centrality(G)

# Sort nodes by closeness centrality in descending order
sorted_closeness = sorted(closeness_centrality.items(), key=lambda item: item[1], reverse=True)

print("Top 10 nodes by Closeness Centrality:")
for node, cc in sorted_closeness[:10]:
    print(f"Node: {node}, Closeness Centrality: {cc:.4f}")

# %% [markdown]
# ### 6. Visualize Node Thickness based on Betweenness Centrality
#
# We re-draw the graph, making the size of each node proportional to its Betweenness Centrality. This will visually represent 'node thickness' or importance within the network.

# %% [markdown]
# ### 1. Get a list of all nodes in the graph

# %%
print(f"Total number of nodes: {G.number_of_nodes()}\n")
print("First 10 nodes (IDs):", list(G.nodes())[:10])

# You can also inspect a specific node's attributes
if 'AAA' in G.nodes():
    print("\nAttributes for node 'AAA':", G.nodes['AAA'])
else:
    print("\nNode 'AAA' not found in the graph.")

# %% [markdown]
# ### 2. Get a list of all edges in the graph

# %%
print(f"Total number of edges: {G.number_of_edges()}\n")
print("First 10 edges (Source, Target, Weight):", list(G.edges(data=True))[:10])

# %% [markdown]
# ### 3. Calculate Betweenness Centrality

# %%
betweenness_centrality = nx.betweenness_centrality(G)

# Sort nodes by betweenness centrality in descending order
sorted_betweenness = sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse=True)

print("Top 10 nodes by Betweenness Centrality:")
for node, bc in sorted_betweenness[:10]:
    print(f"Node: {node}, Betweenness Centrality: {bc:.4f}")
